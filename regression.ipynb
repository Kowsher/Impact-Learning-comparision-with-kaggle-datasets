# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedshuvo969/Impace-Learning-comparision-with-kaggle-datasets/blob/master/regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('Concrete_Data_Yeh.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 8].values
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-9f5c7872169a> in <module>()
#       4
#       5 # Importing the dataset
# ----> 6 dataset = pd.read_csv('Concrete_Data_Yeh.csv')
#       7 X = dataset.iloc[:, :-1].values
#       8 y = dataset.iloc[:, 8].values
#
# ...

# %%
print(y[0])
# Out:
# 79.99

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Predicting the Test set results
y_pred = regressor.predict(X_test)

# %%
cdf = pd.DataFrame(regressor.coef_)
print(cdf)
# Out:
#            0
# 0  12.470751
# 1   9.601679
# 2   5.876634
# 3  -3.109428
# 4   1.882144
# 5   1.729819
# 6   1.823053
# 7   7.117277

# %%
t_data = []
for i in range(len(y_pred)):
  t_data.append(i+1)

# %%
plt.plot(t_data, y_test,'b--' )
plt.plot(t_data,y_pred,'b-',label='learning', c = 'gold')


plt.ylabel('predection')
plt.xlabel('Time')
plt.legend(loc='best')
plt.show()

# %%
print(X_train[0])
# Out:
# [ 1.91868084 -0.88106284 -0.8461832   0.4954066  -1.05983651 -0.46017905
#  -0.64352249 -0.2880169 ]

# %%
y1 = X_train[:, 0]
y2 = X_train[:, 1]
y3 = X_train[:, 2]
y4 = X_train[:, 3]
y5 = X_train[:, 4]
y6 = X_train[:, 5]
y7 = X_train[:, 6]
y8 = X_train[:, 7]

# %%
print(y8[0])
# Out:
# -0.2880169039459619

# %%
yt1 = X_test[:, 0]
yt2 = X_test[:, 1]
yt3 = X_test[:, 2]
yt4 = X_test[:, 3]
yt5 = X_test[:, 4]
yt6 = X_test[:, 5]
yt7 = X_test[:, 6]
yt8 = X_test[:, 7]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-32a1345a8318> in <module>()
# ----> 1 yt1 = X_test[:, 0]
#       2 yt2 = X_test[:, 1]
#       3 yt3 = X_test[:, 2]
#       4 yt4 = X_test[:, 3]
#       5 yt5 = X_test[:, 4]
#
# NameError: name 'X_test' is not defined

# %%
from scipy.optimize import curve_fit
def test_func1(X, a, b, c, d, e, f, g, h, i, j):
 y1, y2, y3, y4, y5, y6, y7, y8 = X
 return ((b/(a))*(a-c*y1-d*y2-e*y3-f*y4-g*y5-h*y6-i*y7-j*y8))
p0 = [2, 2, 2, 2, 2, 2, 2, 2, 2, 2] # initial guesses
c,cov = curve_fit(test_func1, (y1, y2, y3, y4, y5, y6, y7, y8), y_train, p0) # fit model
yx = test_func1((yt1, yt2, yt3, yt4, yt5, yt6, yt7, yt8),c[0],c[1],c[2],c[3],c[4],c[5],c[6], c[7], c[8], c[9])

# %%
print(c)
# Out:
# [2387.61416561   36.10087376 -824.77707086 -635.02449112 -388.66061551
#   205.65287753 -124.47745032 -114.40176214 -120.56766575 -470.7149762 ]

# %%
plt.plot(t_data, y_test,'b--', c = 'red' )
plt.plot(t_data,yx,'b-',label='learning', c = 'blue')


plt.ylabel('predection')
plt.xlabel('Time')
plt.legend(loc='best')
plt.show()

# %%
error1 = 0
for i in range(len(yx)):
    error1 = error1 + (y_test[i] - yx[i])*(y_test[i] - yx[i])

error = 0
for i in range(len(yx)):
    error = error + (y_test[i] - y_pred[i])*(y_test[i] - y_pred[i])

print(error, " ", error1)
# Out:
# 19697.137804015332   19697.127565682425

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('Position_Salaries.csv')
X1 = dataset.iloc[:, 1].values
y1 = dataset.iloc[:, 2].values

# %%
print(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ada22aaedd50> in <module>()
# ----> 1 print(X, y)
#
# NameError: name 'X' is not defined

# %%
from scipy.optimize import curve_fit
def test_func1(y, a, b, c, d, e):
 
 return ((1/(b))*(a-c*y-d*y*y-e*y*y*y-1))
p0 = [2, 2, 2, 2, 2] # initial guesses
c,cov = curve_fit(test_func1, X1, y1, p0) # fit model
yx = test_func1(X1,c[0],c[1],c[2],c[3],c[4])

# %%
plt.plot(X1, y1,'b--', c = 'red' )
plt.plot(X1,yx,'b-',label='learning', c = 'blue')


plt.ylabel('predection')
plt.xlabel('Time')
plt.legend(loc='best')
plt.show()

# %%
print(c)
# Out:
# [-7.44768318e+04  6.13827742e-01 -1.10896859e+05  2.98007122e+04
#  -2.52900017e+03]

# %%
# Polynomial Regression

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:2].values
y = dataset.iloc[:, 2].values

# Splitting the dataset into the Training set and Test set
"""from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)"""

# Feature Scaling
"""from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)"""

# Fitting Linear Regression to the dataset
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)

# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 3)
X_poly = poly_reg.fit_transform(X)
poly_reg.fit(X_poly, y)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)

kk = lin_reg_2.predict(poly_reg.fit_transform(X))

# Visualising the Polynomial Regression results
plt.plot(X, y, color = 'red')
plt.plot(X,kk, color = 'blue')

plt.show()

# %%
error1 = 0
for i in range(len(yx)):
    error1 = error1 + (y1[i] - yx[i])*(y1[i] - yx[i])

error = 0
for i in range(len(yx)):
    error = error + (y1[i] - kk[i])*(y1[i] - kk[i])

print(error, " ", error1)
# Out:
# 15156620046.62004   15156620046.636635

# %%
cdf = pd.DataFrame(lin_reg_2.coef_)
print(cdf)
# Out:
#                0
# 0       0.000000
# 1  180664.335664
# 2  -48548.951049
# 3    4120.046620
